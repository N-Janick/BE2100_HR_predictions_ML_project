# %% [markdown]
# Notebook for Jawad to explore and analyze the data as well as experiment with engineering features.

# %%
# This first cell serves as an example and a base so we are starting with the same variable names and aliases
# I believe you should not need to redeclare variables or import statements in python cells that come after 
# this one, but I am still pretty new to working with notebooks so I could be wrong.
import matplotlib.pyplot as plt
import pandas as pd

# using raw data as demonstration, once cleaned data file is ready comment next line out
raw_data = '../../data/raw/fangraphs_2005-2024_batting_stats_raw.csv' 
data_source = raw_data

# once cleaned data file is created uncomment line below and update file name
# clean_data = '../../data/cleaned/<file name>.csv'
# data_source = clean_data

# creates a dataframe from a dataset to work with the data
df = pd.read_csv(data_source)

# scatter plot to examine realtionship between number of at bats and homeruns hit
plt.scatter(df["AB"], df["HR"])
plt.xlabel("At Bats")
plt.ylabel("Home Runs")
plt.show()
